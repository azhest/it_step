# %%
machines=["пресс-подборщик","грабли","косилка","МЖУ","МТУ"]

# %%
machines
# Out:
# ['пресс-подборщик', 'грабли', 'косилка', 'МЖУ', 'МТУ']

# %%
len(machines)
# Out:
# 5

# %%
machines.append("УСМ-1")#Adds an element at the end of the list

# %%
machines
# Out:
# ['пресс-подборщик', 'грабли', 'косилка', 'МЖУ', 'МТУ', 'УСМ-1']

# %%
trailers=["2ПТС-4","2ПТС-6","ПТС-24","ПС-45"]

# %%
x=trailers.copy()
print(x)
# Out:
# ['2ПТС-4', '2ПТС-6', 'ПТС-24', 'ПС-45']

# %%
machines.append(trailers)
print(machines)
# Out:
# ['пресс-подборщик', 'грабли', 'косилка', 'МЖУ', 'МТУ', 'УСМ-1', ['2ПТС-4', '2ПТС-6', 'ПТС-24', 'ПС-45']]

# %%
trailers.clear()
print(machines)
# Out:
# ['пресс-подборщик', 'грабли', 'косилка', 'МЖУ', 'МТУ', 'УСМ-1', []]

# %%
machines.append(x)
print(machines)
# Out:
# ['пресс-подборщик', 'грабли', 'косилка', 'МЖУ', 'МТУ', 'УСМ-1', [], ['2ПТС-4', '2ПТС-6', 'ПТС-24', 'ПС-45']]

# %%
y=machines.count("МЖУ")#Return the number of times the value appears in the list:
print(y)
# Out:
# 1

# %%
semitrailers=('ПСТ-6','ПСТ-9','ПСТ-12','ПСТ-14')

# %%
machines.extend(semitrailers)#Add the elements of a list (or any iterable), to the end of the current list
print(machines)
# Out:
# ['пресс-подборщик', 'грабли', 'косилка', 'МЖУ', 'МТУ', 'УСМ-1', [], ['2ПТС-4', '2ПТС-6', 'ПТС-24', 'ПС-45'], 'ПСТ-6', 'ПСТ-9', 'ПСТ-12', 'ПСТ-14']

# %%
z=machines.index('МЖУ')#Note:The index() method only returns the first occurrence of the value.
print(z)
# Out:
# 3

# %%
machines.insert(3,'РУ-1600')
x.insert(2,'ПСТБ-17')
print(machines)
# Out:
# ['пресс-подборщик', 'грабли', 'косилка', 'РУ-1600', 'МЖУ', 'МТУ', 'УСМ-1', [], ['2ПТС-4', '2ПТС-6', 'ПСТБ-17', 'ПТС-24', 'ПС-45'], 'ПСТ-6', 'ПСТ-9', 'ПСТ-12', 'ПСТ-14']

# %%
machines.pop(3)
print(machines)
# Out:
# ['пресс-подборщик', 'грабли', 'косилка', 'МЖУ', 'МТУ', 'УСМ-1', [], ['2ПТС-4', '2ПТС-6', 'ПСТБ-17', 'ПТС-24', 'ПС-45'], 'ПСТ-6', 'ПСТ-9', 'ПСТ-12', 'ПСТ-14']

# %%
e=machines.pop(3)
print(e)
# Out:
# МЖУ

# %%
machines
# Out:
# ['пресс-подборщик',
#  'грабли',
#  'косилка',
#  'МТУ',
#  'УСМ-1',
#  [],
#  ['2ПТС-4', '2ПТС-6', 'ПСТБ-17', 'ПТС-24', 'ПС-45'],
#  'ПСТ-6',
#  'ПСТ-9',
#  'ПСТ-12',
#  'ПСТ-14']

# %%
machines.remove('ПСТ-12')
print(machines)
# Out:
# ['пресс-подборщик', 'грабли', 'косилка', 'МТУ', 'УСМ-1', [], ['2ПТС-4', '2ПТС-6', 'ПСТБ-17', 'ПТС-24', 'ПС-45'], 'ПСТ-6', 'ПСТ-9', 'ПСТ-14']

# %%
machines.reverse()
print(machines)
# Out:
# ['ПСТ-14', 'ПСТ-9', 'ПСТ-6', ['2ПТС-4', '2ПТС-6', 'ПСТБ-17', 'ПТС-24', 'ПС-45'], [], 'УСМ-1', 'МТУ', 'косилка', 'грабли', 'пресс-подборщик']

# %%
x.sort()#The sort() method sorts the list ascending by default.
print(x)
# Out:
# ['2ПТС-4', '2ПТС-6', 'ПС-45', 'ПСТБ-17', 'ПТС-24']

# %%
x.sort(reverse=True)#Optional. reverse=True will sort the list descending. Default is reverse=False
print(x)
# Out:
# ['ПТС-24', 'ПСТБ-17', 'ПС-45', '2ПТС-6', '2ПТС-4']
